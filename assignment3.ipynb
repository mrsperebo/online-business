# %% [markdown]
# An online business is looking to optimize sales and cut down on cost due to the economic down turn
#           CRAFT A PROMBLEM STATEMENT
#   >Increasing sales and reducing operational costs are critical objectives for an online business.To achieve sustainable growth and improved profitability the company seeks to identify strategies that effectively optimize sales while minimizing operational expenditure
#
#      FRAME THE PROBLEM WITH RESPECT TO HOW YOUR EXPERTISE CAN HELP THEM SOLVE THE PROBLEM
#    >My expertise lies in analyzing data,identifying trends,and providing actionable insights.I can assist by leveraging data analytics to uncover customer behaviour pattern,optimize marketing strategies and suggest cost-effective operational improvements
#
#      WRITE DOWN STEPS YOU WOULD TAKE TO ARRIVE AT YOUR SOLUTIONS
#
#      >CUSTOMER INSIGHTS
#      >MARKETING OPTIMIZATION
#      >OPERATIONAL EFFICIENCY
#      >COST REDUCTION STRATEGIES
#      >TECHNOLOGY INTEGRATION
#      >PERFORMANCE MONITORING AND ITERATION
#      >REPORTING AND COMMUNICATION

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('Online Retail data.csv',encoding='unicode_escape',dtype=object)
print(data)
# Out:
#        Invoice StockCode                          Description Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS       12
# 1       489434    79323P                   PINK CHERRY LIGHTS       12
# 2       489434    79323W                  WHITE CHERRY LIGHTS       12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE        48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX       24
# ...        ...       ...                                  ...      ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE        2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL        1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL        1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG        2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI        2
#
#             InvoiceDate   Price Customer ID         Country
# ...

# %%
data.head(20)
# Out:
#    Invoice StockCode                          Description Quantity  \
# 0   489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS       12
# 1   489434    79323P                   PINK CHERRY LIGHTS       12
# 2   489434    79323W                  WHITE CHERRY LIGHTS       12
# 3   489434     22041         RECORD FRAME 7" SINGLE SIZE        48
# 4   489434     21232       STRAWBERRY CERAMIC TRINKET BOX       24
# 5   489434     22064           PINK DOUGHNUT TRINKET POT        24
# 6   489434     21871                  SAVE THE PLANET MUG       24
# 7   489434     21523   FANCY FONT HOME SWEET HOME DOORMAT       10
# 8   489435     22350                            CAT BOWL        12
# 9   489435     22349       DOG BOWL , CHASING BALL DESIGN       12
# 10  489435     22195         HEART MEASURING SPOONS LARGE       24
# 11  489435     22353   LUNCHBOX WITH CUTLERY FAIRY CAKES        12
# 12  489436    48173C                DOOR MAT BLACK FLOCK        10
# ...

# %% [markdown]
# the data has duplicate invoice and customer ID,also the date and time are on thesame column,
# The price column,the first two rows were in dollar while the rest of the rows had none

# %%
data['Price']=data['Price'].str.replace('$','')

# %%
data['Price'] = data['Price'].astype('float')
data['Quantity'] = data['Quantity'].astype('float')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525461 entries, 0 to 525460
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Invoice      525461 non-null  object
#  1   StockCode    525461 non-null  object
#  2   Description  522533 non-null  object
#  3   Quantity     525461 non-null  float64
#  4   InvoiceDate  525461 non-null  object
#  5   Price        525461 non-null  float64
#  6   Customer ID  417534 non-null  object
#  7   Country      525461 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 32.1+ MB

# %%
data.describe()
# Out:
#             Quantity          Price
# count  525461.000000  525461.000000
# mean       10.337667       4.688834
# std       107.424110     146.126914
# min     -9600.000000  -53594.360000
# 25%         1.000000       1.250000
# 50%         3.000000       2.100000
# 75%        10.000000       4.210000
# max     19152.000000   25111.090000

# %%
data
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS      12.0
# 1       489434    79323P                   PINK CHERRY LIGHTS      12.0
# 2       489434    79323W                  WHITE CHERRY LIGHTS      12.0
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE       48.0
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX      24.0
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE       2.0
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL       1.0
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL       1.0
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG       2.0
# 525460  538171     21931               JUMBO STORAGE BAG SUKI       2.0
#
#             InvoiceDate  Price Customer ID         Country
# ...

# %%
data.tail(20)
# Out:
#        Invoice StockCode                         Description  Quantity  \
# 525441  538171     22837          HOT WATER BOTTLE BABUSHKA        2.0
# 525442  538171     85152     HAND OVER THE CHOCOLATE   SIGN        3.0
# 525443  538171     21329             DINOSAURS  WRITING SET        2.0
# 525444  538171     21327                 SKULLS WRITING SET        2.0
# 525445  538171     22666     RECIPE BOX PANTRY YELLOW DESIGN       1.0
# 525446  538171     22154         ANGEL DECORATION 3 BUTTONS       48.0
# 525447  538171     21875                    KINGS CHOICE MUG       2.0
# 525448  538171     21871                 SAVE THE PLANET MUG       2.0
# 525449  538171     21877                 HOME SWEET HOME MUG       2.0
# 525450  538171     22747          POPPY'S PLAYHOUSE BATHROOM       2.0
# 525451  538171     22748           POPPY'S PLAYHOUSE KITCHEN       2.0
# 525452  538171     22745          POPPY'S PLAYHOUSE BEDROOM        2.0
# ...

# %%
data[data.isnull()]
# Out:
#        Invoice StockCode Description  Quantity InvoiceDate  Price Customer ID  \
# 0          NaN       NaN         NaN       NaN         NaN    NaN         NaN
# 1          NaN       NaN         NaN       NaN         NaN    NaN         NaN
# 2          NaN       NaN         NaN       NaN         NaN    NaN         NaN
# 3          NaN       NaN         NaN       NaN         NaN    NaN         NaN
# 4          NaN       NaN         NaN       NaN         NaN    NaN         NaN
# ...        ...       ...         ...       ...         ...    ...         ...
# 525456     NaN       NaN         NaN       NaN         NaN    NaN         NaN
# 525457     NaN       NaN         NaN       NaN         NaN    NaN         NaN
# 525458     NaN       NaN         NaN       NaN         NaN    NaN         NaN
# 525459     NaN       NaN         NaN       NaN         NaN    NaN         NaN
# 525460     NaN       NaN         NaN       NaN         NaN    NaN         NaN
#
#        Country
# 0          NaN
# ...

# %%
data.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')

# %%
data.dropna(axis=0,inplace=True)

# %%
data
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS      12.0
# 1       489434    79323P                   PINK CHERRY LIGHTS      12.0
# 2       489434    79323W                  WHITE CHERRY LIGHTS      12.0
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE       48.0
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX      24.0
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE       2.0
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL       1.0
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL       1.0
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG       2.0
# 525460  538171     21931               JUMBO STORAGE BAG SUKI       2.0
#
#             InvoiceDate  Price Customer ID         Country
# ...

# %%
data.duplicated().sum()
# Out:
# 6771

# %%
data.drop_duplicates(inplace=True)

# %%
data
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS      12.0
# 1       489434    79323P                   PINK CHERRY LIGHTS      12.0
# 2       489434    79323W                  WHITE CHERRY LIGHTS      12.0
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE       48.0
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX      24.0
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE       2.0
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL       1.0
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL       1.0
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG       2.0
# 525460  538171     21931               JUMBO STORAGE BAG SUKI       2.0
#
#             InvoiceDate  Price Customer ID         Country
# ...

# %%
data['Country']=data['Country'].replace({'UK':'United kingdom',})

# %%
data
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS      12.0
# 1       489434    79323P                   PINK CHERRY LIGHTS      12.0
# 2       489434    79323W                  WHITE CHERRY LIGHTS      12.0
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE       48.0
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX      24.0
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE       2.0
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL       1.0
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL       1.0
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG       2.0
# 525460  538171     21931               JUMBO STORAGE BAG SUKI       2.0
#
#             InvoiceDate  Price Customer ID         Country
# ...

# %%
data['Country']
# Out:
# 0         United kingdom
# 1         United kingdom
# 2         United kingdom
# 3         United kingdom
# 4         United kingdom
#                ...
# 525456    United Kingdom
# 525457    United Kingdom
# 525458    United Kingdom
# 525459    United Kingdom
# 525460    United Kingdom
# Name: Country, Length: 410763, dtype: object

# %%
data['Price']
# Out:
# 0         6.95
# 1         6.75
# 2         6.75
# 3         2.10
# 4         1.25
#           ...
# 525456    2.95
# 525457    3.75
# 525458    3.75
# 525459    3.75
# 525460    1.95
# Name: Price, Length: 410763, dtype: float64

# %%
data['Description']
# Out:
# 0         15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1                          PINK CHERRY LIGHTS
# 2                         WHITE CHERRY LIGHTS
# 3                RECORD FRAME 7" SINGLE SIZE
# 4              STRAWBERRY CERAMIC TRINKET BOX
#                          ...
# 525456                   FELTCRAFT DOLL ROSIE
# 525457           FELTCRAFT PRINCESS LOLA DOLL
# 525458         FELTCRAFT PRINCESS OLIVIA DOLL
# 525459     PINK FLORAL FELTCRAFT SHOULDER BAG
# 525460                 JUMBO STORAGE BAG SUKI
# Name: Description, Length: 410763, dtype: object

# %%
data
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS      12.0
# 1       489434    79323P                   PINK CHERRY LIGHTS      12.0
# 2       489434    79323W                  WHITE CHERRY LIGHTS      12.0
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE       48.0
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX      24.0
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE       2.0
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL       1.0
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL       1.0
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG       2.0
# 525460  538171     21931               JUMBO STORAGE BAG SUKI       2.0
#
#             InvoiceDate  Price Customer ID         Country
# ...

# %%
data.drop(['Invoice','StockCode','InvoiceDate','Customer ID','Country'], axis=1,inplace=True)

# %%
data
# Out:
#                                 Description  Quantity  Price
# 0       15CM CHRISTMAS GLASS BALL 20 LIGHTS      12.0   6.95
# 1                        PINK CHERRY LIGHTS      12.0   6.75
# 2                       WHITE CHERRY LIGHTS      12.0   6.75
# 3              RECORD FRAME 7" SINGLE SIZE       48.0   2.10
# 4            STRAWBERRY CERAMIC TRINKET BOX      24.0   1.25
# ...                                     ...       ...    ...
# 525456                 FELTCRAFT DOLL ROSIE       2.0   2.95
# 525457         FELTCRAFT PRINCESS LOLA DOLL       1.0   3.75
# 525458       FELTCRAFT PRINCESS OLIVIA DOLL       1.0   3.75
# 525459   PINK FLORAL FELTCRAFT SHOULDER BAG       2.0   3.75
# 525460               JUMBO STORAGE BAG SUKI       2.0   1.95
#
# [410763 rows x 3 columns]

# %%
data.rename(columns={'Price': 'Price ($)'}, inplace=True)
data
# Out:
#                                 Description  Quantity  Price ($)
# 0       15CM CHRISTMAS GLASS BALL 20 LIGHTS      12.0       6.95
# 1                        PINK CHERRY LIGHTS      12.0       6.75
# 2                       WHITE CHERRY LIGHTS      12.0       6.75
# 3              RECORD FRAME 7" SINGLE SIZE       48.0       2.10
# 4            STRAWBERRY CERAMIC TRINKET BOX      24.0       1.25
# ...                                     ...       ...        ...
# 525456                 FELTCRAFT DOLL ROSIE       2.0       2.95
# 525457         FELTCRAFT PRINCESS LOLA DOLL       1.0       3.75
# 525458       FELTCRAFT PRINCESS OLIVIA DOLL       1.0       3.75
# 525459   PINK FLORAL FELTCRAFT SHOULDER BAG       2.0       3.75
# 525460               JUMBO STORAGE BAG SUKI       2.0       1.95
#
# [410763 rows x 3 columns]

# %%
data['Turnover']=data['Quantity'] *data['Price ($)']

# %%
data
# Out:
#                                 Description  Quantity  Price ($)  Turnover
# 0       15CM CHRISTMAS GLASS BALL 20 LIGHTS      12.0       6.95     83.40
# 1                        PINK CHERRY LIGHTS      12.0       6.75     81.00
# 2                       WHITE CHERRY LIGHTS      12.0       6.75     81.00
# 3              RECORD FRAME 7" SINGLE SIZE       48.0       2.10    100.80
# 4            STRAWBERRY CERAMIC TRINKET BOX      24.0       1.25     30.00
# ...                                     ...       ...        ...       ...
# 525456                 FELTCRAFT DOLL ROSIE       2.0       2.95      5.90
# 525457         FELTCRAFT PRINCESS LOLA DOLL       1.0       3.75      3.75
# 525458       FELTCRAFT PRINCESS OLIVIA DOLL       1.0       3.75      3.75
# 525459   PINK FLORAL FELTCRAFT SHOULDER BAG       2.0       3.75      7.50
# 525460               JUMBO STORAGE BAG SUKI       2.0       1.95      3.90
#
# [410763 rows x 4 columns]

# %%
data['Quantity']
# Out:
# 0         12.0
# 1         12.0
# 2         12.0
# 3         48.0
# 4         24.0
#           ...
# 525456     2.0
# 525457     1.0
# 525458     1.0
# 525459     2.0
# 525460     2.0
# Name: Quantity, Length: 410763, dtype: float64

# %% [markdown]
# FORMULATE AND ANSWER ANALYTICAL QUESTIONS TO ADDRESS THE BUSINESS PROBLEM
# STRATEGIC QUESTIONS
# 1: What are the primary channels driving traffic to our website or social media handles
#     while trying to minimize cost is important we focus on increasing our post,shares,likes
#     easy access to our website,through links,email marketing,affiliate marketing.
#     RECOMMENDATION
#     people want an easy way to shop online,so making all our online platforms very seamless to cutomers wil always make them refer
#     more customers,online business is based majorly on referals and what they get when they visit the buisness page.so i recommend the business forcus more on building a seamless accross online platforms
#
# 2: Why are some product selling more as compared to others
#    An online survey should be conducted to know customers preference
#    RECOMMENDATION
#    Business owner should stock up only product that has more turnovers to avoid stocking up too much inventory to avoid damages
#    as seen from the data some product then to sell more
#
# 3: How is our online business performing compared to our competitors
#     Visit their online stores,find out what they are doing to generate more traffic to theier page
#     check if the business is over pricing as compared to competitors
#
#
# 4: How can we optimize inventory management to reduce cost and improve customer satisfaction
#     stocking up inventories with higher demand
#
# 5: How does our cost per acquisition vary across different marketing channels
